# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
# Out:
# StatementMeta(, 6ce88f6c-014f-4abc-92c0-9adfbb742d0d, 3, Finished, Available, Finished)

# %%
# df now is a Spark DataFrame containing JSON data
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, 6ce88f6c-014f-4abc-92c0-9adfbb742d0d, 4, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # df now is a Spark DataFrame containing JSON data
# ----> 2 df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
#
# NameError: name 'start_date' is not defined

# %%
# Reshape earthquake data by extracting and renaming key attributes for further analysis.
df = \
df.\
    select(
        'id',
        col('geometry.coordinates').getItem(0).alias('longitude'),
        col('geometry.coordinates').getItem(1).alias('latitude'),
        col('geometry.coordinates').getItem(2).alias('elevation'),
        col('properties.title').alias('title'),
        col('properties.place').alias('place_description'),
        col('properties.sig').alias('sig'),
        col('properties.mag').alias('mag'),
        col('properties.magType').alias('magType'),
        col('properties.time').alias('time'),
        col('properties.updated').alias('updated')
        )
# Out:
# StatementMeta(, 955bb35c-2838-4dc5-bfac-420639c2223d, 6, Finished, Available, Finished)

# %%
# Convert 'time' and 'updated' columns from milliseconds to timestamp format for clearer datetime representation.
df = df.\
    withColumn('time', col('time')/1000).\
    withColumn('updated', col('updated')/1000).\
    withColumn('time', col('time').cast(TimestampType())).\
    withColumn('updated', col('updated').cast(TimestampType()))
# Out:
# StatementMeta(, 955bb35c-2838-4dc5-bfac-420639c2223d, 9, Finished, Available, Finished)

# %%
# appending the data to the gold table
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, 955bb35c-2838-4dc5-bfac-420639c2223d, 11, Finished, Available, Finished)
